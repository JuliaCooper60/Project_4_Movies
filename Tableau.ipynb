# %%
import pandas as pd
import pandas as pd
import requests
import json
import pprint

# %%
df4.iloc[:,0:2]
# Out:
#            tconst titleType
# 2890    tt0013274     movie
# 3479    tt0015414     movie
# 3582    tt0015724     movie
# 16445   tt0035423     movie
# 18570   tt0038086     movie
# ...           ...       ...
# 370980  tt9916270     movie
# 370981  tt9916362     movie
# 370982  tt9916428     movie
# 370983  tt9916460   tvMovie
# 370984  tt9916544     short
#
# [241066 rows x 2 columns]

# %%
df4.to_csv('./data/list_tconst.csv',index=False)

# %%
df1 = pd.read_csv('./data/omdb.csv',lineterminator='\n')
df1.info()
# df2 =pd.read_csv('./data/raw_consolidate_data.csv',lineterminator='\n')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42095 entries, 0 to 42094
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         42095 non-null  object
#  1   Rated          9341 non-null   object
#  2   Plot           39808 non-null  object
#  3   Awards         18314 non-null  object
#  4   Metascore      4240 non-null   float64
#  5   DVD            14417 non-null  object
#  6   BoxOffice      2728 non-null   object
#  7   Actors         39237 non-null  object
#  8   Released       40581 non-null  object
#  9   Director       41816 non-null  object
#  10  Writer         36379 non-null  object
#  11  rating1source  42095 non-null  object
#  12  rating1value   42095 non-null  object
#  13  rating2source  42095 non-null  object
#  14  rating2value   42095 non-null  object
#  15  rating3source  42095 non-null  object
#   42095 non-null  object
# dtypes: float64(1), object(16)
# ...

# %%
df2 = pd.read_csv('./data/themoviedb.csv',lineterminator='\n')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 810009 entries, 0 to 810008
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   themoviedb_id              810009 non-null  float64
#  1   imdb_id                    500286 non-null  object
#  2   belongs_to_collection      19735 non-null   object
#  3   budget                     810009 non-null  float64
#  4   popularity                 810004 non-null  float64
#  5   original_language          810009 non-null  object
#  6   production_companies_name  380750 non-null  object
#  7   production_companies_id    380755 non-null  float64
#  8   production_countries       489049 non-null  object
#  9   revenue                    810009 non-null  float64
#  10  status                     810009 non-null  object
#  11  vote_average               810004 non-null  float64
#  12  vote_count                 810004 non-null  float64
# ...

# %%
df3 = pd.read_csv('./data/imdbdata.csv',lineterminator='\n')
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1261834 entries, 0 to 1261833
# Data columns (total 17 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   tconst          1261834 non-null  object
#  1   titleType       1261834 non-null  object
#  2   primaryTitle    1261834 non-null  object
#  3   originalTitle   1261834 non-null  object
#  4   isAdult         1261834 non-null  int64
#  5   startYear       1261834 non-null  int64
#  6   endYear         1261834 non-null  int64
#  7   runtimeMinutes  1261834 non-null  int64
#  8   genres          1261832 non-null  object
#  9   averageRating   1261834 non-null  float64
#  10  numVotes        1261834 non-null  int64
#  11  language        1261834 non-null  float64
#  12  directors       1261834 non-null  object
#  13  writers         1261834 non-null  object
#  14  parentTconst    1261834 non-null  object
#  15  seasonNumber    1261834 non-null  int64
# ...

# %%
# df3 = pd.read_csv('./data/imdbdata.csv')
# df2 = pd.read_csv('./data/themoviedb.csv')
df2.rename(columns={'imdb_id':'tconst'},inplace=True)
df4= df3.merge(df2,how='outer',on='tconst')

# %%
df4
# Out:
#              tconst titleType            primaryTitle           originalTitle  \
# 0         tt0000001     short              Carmencita              Carmencita
# 1         tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2         tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3         tt0000004     short             Un bon bock             Un bon bock
# 4         tt0000005     short        Blacksmith Scene        Blacksmith Scene
# ...             ...       ...                     ...                     ...
# 1700853  tt11278708       NaN                     NaN                     NaN
# 1700854   tt4336518       NaN                     NaN                     NaN
# 1700855  tt11140466       NaN                     NaN                     NaN
# 1700856   tt9621122       NaN                     NaN                     NaN
# 1700857  tt10240166       NaN                     NaN                     NaN
#
# ...

# %%
df4.to_csv('./data/combined_tableau.csv',index=False)

# %%
df4=df4.loc[df4.startYear>1990,:]

# %%
df4.to_csv('./data/combined_tableau2.csv',index=False)

# %%
# df3 = pd.read_csv('./data/imdbdata.csv')
# df2 = pd.read_csv('./data/themoviedb.csv')
df2.rename(columns={'imdb_id':'tconst'},inplace=True)
df4= df3.merge(df2,how='inner',on='tconst')

# %%
df4
# Out:
#            tconst titleType              primaryTitle  \
# 0       tt0000001     short                Carmencita
# 1       tt0000002     short    Le clown et ses chiens
# 2       tt0000003     short            Pauvre Pierrot
# 3       tt0000004     short               Un bon bock
# 4       tt0000005     short          Blacksmith Scene
# ...           ...       ...                       ...
# 370980  tt9916270     movie  Il talento del calabrone
# 370981  tt9916362     movie                     Coven
# 370982  tt9916428     movie       The Secret of China
# 370983  tt9916460   tvMovie                 Pink Taxi
# 370984  tt9916544     short           My Sweet Prince
#
#                        originalTitle  isAdult  startYear  endYear  \
# 0                         Carmencita        0       1894        0
# 1             Le clown et ses chiens        0       1892        0
# 2                     Pauvre Pierrot        0       1892        0
# ...

# %%
df4.loc[df4.startYear>1990,:]
# Out:
#            tconst titleType                 primaryTitle  \
# 2890    tt0013274     movie  Istoriya grazhdanskoy voyny
# 3479    tt0015414     movie       La tierra de los toros
# 3582    tt0015724     movie                Dama de noche
# 16445   tt0035423     movie               Kate & Leopold
# 18570   tt0038086     movie    Shiva und die Galgenblume
# ...           ...       ...                          ...
# 370980  tt9916270     movie     Il talento del calabrone
# 370981  tt9916362     movie                        Coven
# 370982  tt9916428     movie          The Secret of China
# 370983  tt9916460   tvMovie                    Pink Taxi
# 370984  tt9916544     short              My Sweet Prince
#
#                        originalTitle  isAdult  startYear  endYear  \
# 2890     Istoriya grazhdanskoy voyny        0       2021        0
# 3479          La tierra de los toros        0       2000        0
# 3582                   Dama de noche        0       1993        0
# ...

# %%
df4.to_csv('./data/combined_tableau4.csv',index=False)

# %%
movie_url = "https://api.themoviedb.org/3/genre/movie/list?api_key=" + str("api)key=d31aa51f6a9e056a046877d19cc1ff2f") + "&language=en-US=en-US"
movie_genres = requests.get(movie_url).json()['genres']
pprint.pprint(movie_genres)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/h4/302vnt9j1kb09wlh6m55qbt40000gn/T/ipykernel_59657/1362325838.py in <module>
#       1 movie_url = "https://api.themoviedb.org/3/genre/movie/list?api_key=" + str("api)key=d31aa51f6a9e056a046877d19cc1ff2f") + "&language=en-US=en-US"
# ----> 2 movie_genres = requests.get(movie_url).json()['genres']
#       3 pprint.pprint(movie_genres)
#
# KeyError: 'genres'
